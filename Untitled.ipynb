# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("Dis.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Season_Year dismissal_kind s_team  wickets
# 0           1         2008         bowled    CSK       11
# 1           2         2008         bowled     DC       16
# 2           3         2008         bowled     DD       16
# 3           4         2008         bowled    KKR       17
# 4           5         2008         bowled   KXIP        9

# %%
df["Season_Year"] = df["Season_Year"].astype(int)
df = df.T
df = df.replace(np.nan, 0)
new_header = df.iloc[0]
df = df[1:]
df.columns = new_header
df.head()
# Out:
# Unnamed: 0         1       2       3       4       5       6       7    \
# Season_Year       2008    2008    2008    2008    2008    2008    2008
# dismissal_kind  bowled  bowled  bowled  bowled  bowled  bowled  bowled
# s_team             CSK      DC      DD     KKR    KXIP      MI     RCB
# wickets             11      16      16      17       9      18      22
#
# Unnamed: 0         8       9       10   ...      457      458      459  \
# Season_Year       2008    2008    2008  ...     2016     2016     2016
# dismissal_kind  bowled  caught  caught  ...  stumped  stumped  stumped
# s_team              RR     CSK      DC  ...     KXIP       MI      RCB
# wickets             20      49      58  ...        3        1        1
#
# Unnamed: 0          460      461     462     463     464      465      466
# Season_Year        2016     2016    2017    2017    2017     2017     2017
# dismissal_kind  stumped  stumped  bowled  caught  caught  run out  run out
# s_team              RPS      SRH     RCB     RCB     SRH      RCB      SRH
# wickets               6        2       2       3       6        2        1
#
# [4 rows x 466 columns]
